# %% [markdown]
# # Project 03 -- Anthony Micco

# %% [markdown]
# **TA Help:** N/A
#
# **Collaboration:** N/A

# %% [markdown]
# ## Question 1

# %%
# code to read files 
list.files("/anvil/projects/tdm/data/craigslist")
file.info("/anvil/projects/tdm/data/craigslist/vehicles.csv")$size
# Out:
# [1] "vehicles.csv"       "vehicles_clean.txt"
# [1] 1447955215

# %%
# code to create data frame
myDF <- read.csv("/anvil/projects/tdm/data/craigslist/vehicles.csv")

# %%
# code to get the number of rows and columns
dim(myDF)

#code to get the data types 
str(myDF)
# Out:
# [1] 426880     26
# 'data.frame':	426880 obs. of  26 variables:
#  $ id          : num  7.22e+09 7.22e+09 7.22e+09 7.22e+09 7.21e+09 ...
#  $ url         : chr  "https://prescott.craigslist.org/cto/d/prescott-2010-ford-ranger/7222695916.html" "https://fayar.craigslist.org/ctd/d/bentonville-2017-hyundai-elantra-se/7218891961.html" "https://keys.craigslist.org/cto/d/summerland-key-2005-excursion/7221797935.html" "https://worcester.craigslist.org/cto/d/west-brookfield-2002-honda-odyssey-ex/7222270760.html" ...
#  $ region      : chr  "prescott" "fayetteville" "florida keys" "worcester / central MA" ...
#  $ region_url  : chr  "https://prescott.craigslist.org" "https://fayar.craigslist.org" "https://keys.craigslist.org" "https://worcester.craigslist.org" ...
#  $ price       : num  6000 11900 21000 1500 4900 ...
#  $ year        : int  NA NA NA NA NA NA NA NA NA NA ...
#  $ manufacturer: chr  "" "" "" "" ...
#  $ model       : chr  "" "" "" "" ...
#  $ condition   : chr  "" "" "" "" ...
# ...

# %% [markdown]
# A) Our dataframe has 426880 rows and 26 columns.
#
# B) The data frame uses logical (boolean) values, characters, doubles, and integers.
#
# C) From the short summary of our data frame's variables, I would expect our data frame to include data about cars for sale and their description. The data includes model, year, manufacturer, and price, as well as other important information a car buyer would require.

# %% [markdown]
# ## Question 2

# %%
# code to get the number of number of NA values 
sum(is.na(myDF$year))
dim(myDF)[1]

# code to get percentage 
sum(is.na(myDF$year)) / dim(myDF)[1]
# Out:
# [1] 1205
# [1] 426880
# [1] 0.002822807

# %%
# Creating the goodyearsDF
goodyearsDF <- subset(myDF, !is.na(year))
head(goodyearsDF)
# Out:
#    id
# 28 7316814884
# 29 7316814758
# 30 7316814989
# 31 7316743432
# 32 7316356412
# 33 7316343444
#    url
# 28 https://auburn.craigslist.org/ctd/d/auburn-university-2014-gmc-sierra-1500/7316814884.html
# 29 https://auburn.craigslist.org/ctd/d/auburn-university-2010-chevy-chevrolet/7316814758.html
# 30 https://auburn.craigslist.org/ctd/d/auburn-university-2020-chevy-chevrolet/7316814989.html
# 31 https://auburn.craigslist.org/ctd/d/auburn-university-2017-toyota-tundra/7316743432.html
# 32 https://auburn.craigslist.org/cto/d/auburn-university-2013-150/7316356412.html
# 33 https://auburn.craigslist.org/ctd/d/auburn-university-2012-gmc-sierra-2500/7316343444.html
#    region region_url                    price year manufacturer
# 28 auburn https://auburn.craigslist.org 33590 2014 gmc
# 29 auburn https://auburn.craigslist.org 22590 2010 chevrolet
# 30 auburn https://auburn.craigslist.org 39590 2020 chevrolet
# 31 auburn https://auburn.craigslist.org 30990 2017 toyota
# ...

# %%
#code to create missingyearsDF
missingyearsDF <- subset(myDF, is.na(year))
head(missingyearsDF)
# Out:
#   id
# 1 7222695916
# 2 7218891961
# 3 7221797935
# 4 7222270760
# 5 7210384030
# 6 7222379453
#   url
# 1 https://prescott.craigslist.org/cto/d/prescott-2010-ford-ranger/7222695916.html
# 2 https://fayar.craigslist.org/ctd/d/bentonville-2017-hyundai-elantra-se/7218891961.html
# 3 https://keys.craigslist.org/cto/d/summerland-key-2005-excursion/7221797935.html
# 4 https://worcester.craigslist.org/cto/d/west-brookfield-2002-honda-odyssey-ex/7222270760.html
# 5 https://greensboro.craigslist.org/cto/d/trinity-1965-chevrolet-truck/7210384030.html
# 6 https://hudsonvalley.craigslist.org/cto/d/westtown-2007-ford-150/7222379453.html
#   region                 region_url                          price year
# 1 prescott               https://prescott.craigslist.org      6000 NA
# 2 fayetteville           https://fayar.craigslist.org        11900 NA
# 3 florida keys           https://keys.craigslist.org         21000 NA
# 4 worcester / central MA https://worcester.craigslist.org     1500 NA
# ...

# %% [markdown]
# A)There are 1205 values in the year column that are 'NA' values. This represents less than one percent (0.2 %) of the total number of rows.

# %% [markdown]
# ## Question 3

# %%
# code to find the mean price of vehicles
subset(aggregate(price ~ year, data= myDF, FUN=mean), year>2002)
# Out:
#     year price
# 95  2003   24268.185
# 96  2004    7505.400
# 97  2005    7950.689
# 98  2006  105032.821
# 99  2007  261162.517
# 100 2008   16993.552
# 101 2009    9071.533
# 102 2010   10252.555
# 103 2011   12503.809
# 104 2012   14089.052
# 105 2013   14748.418
# 106 2014   17144.156
# 107 2015   23408.126
# 108 2016   21495.990
# 109 2017   23970.339
# 110 2018   26368.606
# 111 2019   32975.532
# 112 2020   91897.715
# 113 2021 1338055.311
# 114 2022   27367.053

# %%
#code to find the most frequent year 
which.max(table(myDF$year))
# Out:
# 2017
#  109

# %% [markdown]
# A)2003	24268.185
# 2004	7505.400
# 2005	7950.68
# 2006	105032.821
# 2007	261162.517
# 2008	16993.552
# 2009	9071.533
# 2010	10252.555
# 2011	12503.809
# 2012	14089.052
# 2013	14748.418
# 2014	17144.156
# 2015	23408.126
# 2016	21495.990
# 2017	23970.339
# 2018	26368.606
# 2019	32975.532
# 2020	91897.71
# 2021	1338055.311
# 2022	27367.053
#
# B) The most frequent year in our data is 2017, which occurred 109 times.

# %% [markdown]
# ## Question 4

# %%
# code to find the most popular region_url
tail(sort(table(myDF$region_url)))
# Out:
#    https://bend.craigslist.org   https://omaha.craigslist.org
#                           2982                           2982
#  https://fresno.craigslist.org https://orlando.craigslist.org
#                           2983                           2983
#  https://eugene.craigslist.org https://spokane.craigslist.org
#                           2985                           2988

# %%
# code to find the most popular three states
tail(sort(table(myDF$state)))
# Out:
#    or    oh    ny    tx    fl    ca
# 17104 17696 19386 22945 28511 50614

# %% [markdown]
# A) The most popular region_url is Spokane.
#
# B)The three most popular states are Texas, Florida and California.

# %% [markdown]
# ## Question 5

# %%
# code to create a scatter plot of means from the year 2003-2022
myyears <-subset(aggregate(price ~ year, data= myDF, FUN=mean), year>2002)$year
myprice <-subset(aggregate(price ~ year, data= myDF, FUN=mean), year>2002)$price
plot(myyears[myprice<50000], myprice[myprice<50000], xlab="Year",ylab="Price ($)")
# Out:
# plot without title

# %%
# code to create a line plot of means from the year 2003-2022
myyears <-subset(aggregate(price ~ year, data= myDF, FUN=mean), year>2002)$year
myprice <-subset(aggregate(price ~ year, data= myDF, FUN=mean), year>2002)$price
plot(myyears[myprice<50000], myprice[myprice<50000], type="l", xlab="Year",ylab="Price ($)")
# Out:
# plot without title

# %% [markdown]
# B) One observation I have made from the data is that since about 2009, the average price of cars has increased for the most part with a few, small dips coming in 2016 and 2020. Furthermore, I noticed the sudden, sharp drops in average price between 2003 and 2004, as well as between 2008 and 2009.In addition, the plot has a single outlier in 2019, with it being the only year where the average price was over $30000.

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
